# %% [markdown]
# # ECE-2112-PA4

# %% [markdown]
# Paulene Anne V. Perena <br>
# 2ECE-D

# %%
import pandas as pd

# %%
ECE_Board_Exam_2 = pd.read_excel('board2.xlsx')
ECE_Board_Exam_2
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %% [markdown]
# # A. Visayas Communication DataFrame

# %%
ECE_Board_Exam_2['Average'] = ECE_Board_Exam_2[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1)
ECE_Board_Exam_2['Average']
# Out:
# 0     75.00
# 1     67.25
# 2     72.75
# 3     70.50
# 4     69.00
# 5     75.50
# 6     58.50
# 7     61.75
# 8     47.75
# 9     67.25
# 10    54.75
# 11    76.00
# 12    62.25
# 13    80.50
# 14    59.00
# 15    77.25
# 16    70.50
# 17    63.50
# 18    73.00
# 19    66.50
# 20    68.50
# 21    62.50
# 22    68.75
# 23    57.75
# 24    75.25
# 25    65.75
# 26    60.75
# 27    67.75
# 28    63.50
# 29    68.00
# Name: Average, dtype: float64

# %%
VisComm = ECE_Board_Exam_2[(ECE_Board_Exam_2['Hometown'] == 'Visayas') & (ECE_Board_Exam_2['Track'] == 'Communication')]
VisComm
# Out:
#    Name  Gender          Track Hometown  Math  Electronics  GEAS  \
# 10  S11  Female  Communication  Visayas    48           56    48
# 11  S12    Male  Communication  Visayas    89           67    84
# 17  S18    Male  Communication  Visayas    81           40    81
# 21  S22  Female  Communication  Visayas    64           39    89
# 27  S28    Male  Communication  Visayas    85           53    80
#
#     Communication  Average
# 10             67    54.75
# 11             64    76.00
# 17             52    63.50
# 21             58    62.50
# 27             53    67.75

# %%
VisComm = VisComm[['Name', 'Gender', 'Math', 'Electronics', 'Average']]
VisComm
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75

# %%
rows = len(VisComm)
rows
# Out:
# 5

# %% [markdown]
# # B. Visayas Female DataFrame

# %%
VisFemale = ECE_Board_Exam_2[(ECE_Board_Exam_2['Hometown'] == 'Visayas') & (ECE_Board_Exam_2['Gender'] == 'Female')][['Name', 'Track', 'GEAS', 'Electronics', 'Average']]
VisFemale
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 23  S24  Microelectronics    60           45    57.75
# 25  S26   Instrumentation    83           47    65.75

# %%
VisFemale.loc[(VisFemale['Average']>=60)]
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 25  S26   Instrumentation    83           47    65.75

# %% [markdown]
# # C. CATEGORY-AVERAGE VISUALIZATION

# %% [markdown]
# a.

# %%
Summary_of_Track = ECE_Board_Exam_2.groupby('Track')['Average'].mean().reset_index()
Summary_of_Gender =ECE_Board_Exam_2.groupby('Gender')['Average'].mean().reset_index()
Summary_of_Hometown = ECE_Board_Exam_2.groupby('Hometown')['Average'].mean().reset_index()

# %% [markdown]
# b.

# %%
display(Summary_of_Track)
display(Summary_of_Gender)
display(Summary_of_Hometown)
# Out:
#               Track  Average
# 0     Communication   67.975
# 1   Instrumentation   65.225
# 2  Microelectronics   67.500
#    Gender    Average
# 0  Female  66.616667
# 1    Male  67.183333
#    Hometown    Average
# 0     Luzon  68.083333
# 1  Mindanao  66.678571
# 2   Visayas  65.750000

# %% [markdown]
# c.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,5))

plt.subplot(1, 3, 1)
plt.bar(Summary_of_Track['Track'], Summary_of_Track['Average'])
plt.ylim(0, 100)
plt.title('Summary of Track')
plt.xlabel('Track')
plt.ylabel('Mean Average Score')

plt.subplot(1, 3, 2)
plt.bar(Summary_of_Gender['Gender'], Summary_of_Gender['Average'])
plt.ylim(0, 100)
plt.title('Summary of Gender')
plt.xlabel('Gender')
plt.ylabel('Mean Average Score')


plt.subplot(1, 3, 3)
plt.bar(Summary_of_Hometown['Hometown'], Summary_of_Hometown['Average'])
plt.ylim(0, 100)
plt.title('Summary of Hometown')
plt.xlabel('Hometown')
plt.ylabel('Mean Average Score')

plt.figtext(-0.02, -0.01, "Interpretation", fontsize = 20)
plt.figtext(-0.02, -0.06, "* In terms of Track performance, Communication achieved the highest board exam average, followed by Microelectronics, leaving Instrumentation as the lowest.", fontsize = 16)
plt.figtext(-0.02, -0.12, "* In terms of Gender, Male Board Exam Takers performed well making them the highest average in comparison to Female.", fontsize = 16)
plt.figtext(-0.02, -0.18, "* In terms of Hometown, student takers from Luzon gathered the highest performance, followed by Mindanao, and Visayas being the lowest.", fontsize = 16)

plt.tight_layout()
